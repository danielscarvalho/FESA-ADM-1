# %% [markdown]
# ## CEFSA - FESA - ADM
# ## Jupyter Notebook e Pandas (data frame)
#
# Análise de dados com Python, Jupyter Notebook e Pandas (data frame)

# %%
import pandas as pd

# %%
df_info = pd.read_csv("info.csv",sep=";", decimal=",", encoding="latin1" )

# %%
type(df_info)
# Out:
# pandas.core.frame.DataFrame

# %%
df_info
# Out:
#       ID         VAL  QTD CAT
# 0      0  952.961423  184   A
# 1      1  149.879496  193   A
# 2      2  849.534176  168   A
# 3      3  836.662725  198   C
# 4      4  584.272158  114   C
# ..   ...         ...  ...  ..
# 995  995  190.988675  194   A
# 996  996  860.667151  197   C
# 997  997  366.270081  182   D
# 998  998  932.746046  193   A
# 999  999  326.704121  119   A
#
# [1000 rows x 4 columns]

# %%
df_info.head()
# Out:
#    ID         VAL  QTD CAT
# 0   0  952.961423  184   A
# 1   1  149.879496  193   A
# 2   2  849.534176  168   A
# 3   3  836.662725  198   C
# 4   4  584.272158  114   C

# %%
df_info.tail()
# Out:
#       ID         VAL  QTD CAT
# 995  995  190.988675  194   A
# 996  996  860.667151  197   C
# 997  997  366.270081  182   D
# 998  998  932.746046  193   A
# 999  999  326.704121  119   A

# %%
df_info.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_info.T
# Out:
#          0        1        2        3        4        5        6        7    \
# ID         0        1        2        3        4        5        6        7
# VAL  952.961  149.879  849.534  836.663  584.272  397.519  874.511  210.028
# QTD      184      193      168      198      114      163      143      148
# CAT        A        A        A        C        C        A        A        A
#
#          8       9    ...      990      991      992      993      994  \
# ID         8       9  ...      990      991      992      993      994
# VAL  203.458  433.18  ...  734.412  460.038  803.966  901.884  596.195
# QTD      143     112  ...      158      115      190      131      153
# CAT        A       D  ...        C        D        D        A        D
#
#          995      996     997      998      999
# ID       995      996     997      998      999
# VAL  190.989  860.667  366.27  932.746  326.704
# QTD      194      197     182      193      119
# ...

# %%
df_info.describe()
# Out:
#                 ID          VAL          QTD
# count  1000.000000  1000.000000  1000.000000
# mean    499.500000   496.378376   150.353000
# std     288.819436   289.967653    29.728036
# min       0.000000     5.700571   100.000000
# 25%     249.750000   232.800838   122.750000
# 50%     499.500000   498.702061   152.000000
# 75%     749.250000   749.169245   176.000000
# max     999.000000   998.588008   200.000000

# %%
df_info.sort_values(by="QTD")
# Out:
#       ID         VAL  QTD CAT
# 734  734  428.153179  100   A
# 452  452  183.314055  100   B
# 620  620  430.036846  100   B
# 916  916  990.968870  100   B
# 614  614  226.084108  100   B
# ..   ...         ...  ...  ..
# 200  200  402.071489  200   C
# 756  756   48.542954  200   A
# 622  622   44.847919  200   C
# 727  727  742.132831  200   D
# 777  777  474.517157  200   A
#
# [1000 rows x 4 columns]

# %%
df_info.sort_values(by="QTD").tail()
# Out:
#       ID         VAL  QTD CAT
# 200  200  402.071489  200   C
# 756  756   48.542954  200   A
# 622  622   44.847919  200   C
# 727  727  742.132831  200   D
# 777  777  474.517157  200   A

# %%
df_info.QTD.mean()
# Out:
# 150.353

# %%
df_info.QTD.max()
# Out:
# 200

# %%
df_info.VAL.min()
# Out:
# 5.70057113251754

# %%
df_info[df_info.QTD > 150].mean()
# Out:
# ID     492.883268
# VAL    502.802438
# QTD    175.719844
# dtype: float64

# %%
df_info.groupby("CAT").sum()
# Out:
#          ID            VAL    QTD
# CAT
# A    122877  122938.228528  38047
# B    120549  119686.474912  37434
# C    117511  119428.862931  35889
# D    138563  134324.809262  38983

# %%
df_info.groupby("CAT").mean()
# Out:
#              ID         VAL         QTD
# CAT
# A    483.767717  484.008774  149.791339
# B    486.084677  482.606754  150.943548
# C    489.629167  497.620262  149.537500
# D    537.065891  520.638796  151.096899

# %%
df_info[df_info.CAT == "A"]
# Out:
#       ID         VAL  QTD CAT
# 0      0  952.961423  184   A
# 1      1  149.879496  193   A
# 2      2  849.534176  168   A
# 5      5  397.518990  163   A
# 6      6  874.511359  143   A
# ..   ...         ...  ...  ..
# 978  978   32.521335  193   A
# 993  993  901.883969  131   A
# 995  995  190.988675  194   A
# 998  998  932.746046  193   A
# 999  999  326.704121  119   A
#
# [254 rows x 4 columns]

# %% [markdown]
# Operadores lógicos
#
#  &   and<br>
#  |   or
#
#  Note que a query é informada dentro de um string (texto)

# %%
df_info.query('CAT == "A" & QTD > 150')
# Out:
#       ID         VAL  QTD CAT
# 0      0  952.961423  184   A
# 1      1  149.879496  193   A
# 2      2  849.534176  168   A
# 5      5  397.518990  163   A
# 11    11  242.810461  152   A
# ..   ...         ...  ...  ..
# 960  960  989.175732  173   A
# 961  961  713.642247  153   A
# 978  978   32.521335  193   A
# 995  995  190.988675  194   A
# 998  998  932.746046  193   A
#
# [130 rows x 4 columns]

# %%
df_info.query('CAT != "A" & QTD > 170')
# Out:
#       ID         VAL  QTD CAT
# 3      3  836.662725  198   C
# 12    12  892.321082  176   C
# 15    15  111.251141  198   C
# 20    20  134.801779  195   D
# 23    23  983.822186  187   B
# ..   ...         ...  ...  ..
# 984  984  465.456876  171   D
# 989  989  528.927593  183   C
# 992  992  803.966364  190   D
# 996  996  860.667151  197   C
# 997  997  366.270081  182   D
#
# [240 rows x 4 columns]

# %%
df_info[df_info["CAT"] == "C"]
# Out:
#       ID         VAL  QTD CAT
# 3      3  836.662725  198   C
# 4      4  584.272158  114   C
# 12    12  892.321082  176   C
# 15    15  111.251141  198   C
# 22    22  262.384642  141   C
# ..   ...         ...  ...  ..
# 977  977  487.148949  148   C
# 988  988  171.958865  116   C
# 989  989  528.927593  183   C
# 990  990  734.412347  158   C
# 996  996  860.667151  197   C
#
# [240 rows x 4 columns]

# %%
df_info[df_info.QTD == 119]
# Out:
#       ID         VAL  QTD CAT
# 55    55  107.938766  119   A
# 106  106  286.751115  119   C
# 280  280  409.299467  119   A
# 343  343  713.810204  119   B
# 441  441  195.878551  119   C
# 494  494   72.315434  119   C
# 539  539  269.066700  119   D
# 706  706  617.630122  119   A
# 720  720  765.264435  119   A
# 790  790  853.545312  119   D
# 999  999  326.704121  119   A

# %%
df_info[df_info.ID == 800]
# Out:
#       ID         VAL  QTD CAT
# 800  800  581.019835  154   D

# %%
df_info[df_info.QTD > 190]
# Out:
#       ID         VAL  QTD CAT
# 1      1  149.879496  193   A
# 3      3  836.662725  198   C
# 15    15  111.251141  198   C
# 20    20  134.801779  195   D
# 30    30  696.700439  196   C
# ..   ...         ...  ...  ..
# 975  975   96.328142  192   C
# 978  978   32.521335  193   A
# 995  995  190.988675  194   A
# 996  996  860.667151  197   C
# 998  998  932.746046  193   A
#
# [99 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

df_info.plot.scatter(x='QTD',y='VAL')
plt.show()

# %%
df_info[df_info.CAT=="A"].plot.scatter(x='QTD',y='VAL')
plt.show()

# %%
df_info["QTD"].plot.hist()
plt.show()

# %%
df_info["VAL"].plot.hist()
plt.show()

# %% [markdown]
# Referências:
#
# - https://www.w3schools.com/python/pandas/default.asp
# - https://pandas.pydata.org/docs/user_guide/10min.html
# - https://medium.com/horadecodar/como-usar-o-query-do-pandas-fdf4a00727dc
# - https://wesmckinney.com/book/pandas-basics.html

# %% [markdown]
# Só para lembrar:
#
# Nos arquivos latinos e do Brasil, nosso CSV usa **;** como separador dos campos e **,** como separador de decimal nos números
#
# Nos arquivos americanos e ingleses, o CSV usa **,** como separador de campos e **.** como separador de decimal nos números
#
# <img src="data:image/png;base64,...">

# %% [markdown]
# Usamos básicamente 3 tipos de tabelas de caracteres (character map - charmap) no Brasil.
#
# - latin1 (iso-8859-1)
# - ascii
# - utf8
#
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
# - https://docs.python.org/3/library/codecs.html#standard-encodings
