# %% [markdown]
# # CEFSA
# ## FESA
# ### ADM

# %% [markdown]
# Markdown para editar texto
#
# - https://www.markdowntutorial.com/

# %%
123+3/5
# Out:
# 123.6

# %%
val=0
for i in range(10):
    val += i
val
# Out:
# 45

# %%
import math

math.degrees(math.sin(math.radians(30)))
# Out:
# 28.647889756541158

# %%
x=10

# %%
x
# Out:
# 10

# %%
(x+20)**2
# Out:
# 900

# %%
import random

# %%
random.random()
# Out:
# 0.18498296978192152

# %%
val = [random.random()*100 for r in range(100)]

# %%
val
# Out:
# [61.23405703376563,
#  3.553473355068726,
#  12.214583217760932,
#  96.18895747622473,
#  14.977242205240715,
#  24.091829116047226,
#  33.202532965276774,
#  44.8320097885992,
#  77.07157219648522,
#  51.557122846652014,
#  12.691912112392679,
#  97.7649221557279,
#  0.7654097146804095,
#  27.773888943696377,
#  78.28170547937451,
#  58.540595258731344,
#  5.425680487207096,
#  74.32547082701112,
#  97.21636513743992,
#  28.497979920872396,
#  85.21687059244718,
#  67.11445265629102,
#  87.06105395871458,
#  50.74628184055964,
#  6.46897454338381,
#  97.23551323099835,
#  41.77376277913939,
#  24.78033341488377,
#  61.55761015568596,
#  2.584513080084294,
#  27.971021091886417,
#  11.66558377157898,
#  18.530939643340705,
#  97.27121468431758,
#  39.296453001663956,
#  4.339366962470603,
#  59.06743950848349,
#  3.0368396079279325,
#  84.85523088267637,
#  49.98807744044017,
#  0.8073275013966819,
#  50.29644560030464,
#  41.212864144289796,
#  38.156421222929595,
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(range(100), val)
plt.show()
